# %% [markdown]
# # Load dataset XOR

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ls "/content/gdrive/My Drive/Colab Notebooks"
# Out:
# Mounted at /content/gdrive
#  Dia1  'Machine Learning'		      Perú     WordCloud.ipynb
#  Dia2   Paper-Undersampling-HIV-vif-dataset   Tareas

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_data_1 = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/Machine Learning/XOR.csv", header=None)
df_data_1.head()

#print(df_data_1)
X = df_data_1[[0,1]].to_numpy()
Y = df_data_1[2].to_numpy()

plt.figure(figsize=(4, 4))
plt.scatter(X[:, 0], X[:, 1], c=Y)
plt.title("Dataset")
# Out:
# Text(0.5, 1.0, 'Dataset')

# %% [markdown]
# Print data, inputs and outputs for training

# %%
X
# Out:
# array([[0, 0],
#        [0, 1],
#        [1, 0],
#        [1, 1]])

# %%
Y
# Out:
# array([0, 1, 1, 0])

# %% [markdown]
# Create the SVM

# %%
from sklearn.svm import SVC
C = 1;
gamma = 1;
clf = SVC(C=C, gamma=gamma)

# %% [markdown]
# Learning with SVM

# %%
clf.fit(X,Y)
# Out:
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %% [markdown]
# Testing, output from SVM

# %%
y_pred = clf.predict(X_test)
print(y_pred)
# Out:
# [0 1 1 0]

# %% [markdown]
# Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
error = mean_squared_error(Y,y_pred)
print(error)
# Out:
# 0.0
